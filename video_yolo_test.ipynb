# %% [markdown]
# <a href="https://colab.research.google.com/github/flexitvibez/Reana/blob/main/video_yolo_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UPLOAD TRAINED MODEL

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/Trained_dataset1/my_model.zip /content
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# INSTALL YOLOV8

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# IMPORT YOLO

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# unzip the zip file

# %%
# Unzip images to a custom data folder
# !unzip -q /content/my_model.zip -d /content/custom_data

# %% [markdown]
# LOAD THE MODEL

# %%
model = YOLO('/content/custom_data/train/weights/best.pt')

# %% [markdown]
# LOCATE THE VIDEO

# %%
video_path = '/Bellevue_116th_NE12th__2017-09-10_19-08-25.mp4'

# %% [markdown]
# RUN DETECTION ON VIDEO

# %%
results = model.predict(
    source=video_path,
    save=True,
    conf=0.25
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/107117) /Bellevue_116th_NE12th__2017-09-10_19-08-25.mp4: 384x640 (no detections), 63.4ms
# video 1/1 (frame 2/107117) /Bellevue_116th_NE12th__2017-09-10_19-08-25.mp4: 384x640 (no detections), 6.4ms
# video 1/1 (frame 3/107117) /Bellevue_116th_NE12th__2017-09-10_19-08-25.mp4: 384x640 (no detections), 6.0ms
# video 1/1 (frame 4/107117) /Bellevue_116th_NE12th__2017-09-10_19-08-25.mp4: 384x640 (no detections), 6.0ms
# ...

# %% [markdown]
# VIEW OUTPUT VIDEO

# %%
# !ls runs/detect/predict

# %% [markdown]
# DISPLAY IT

# %%
from IPython.display import Video

Video('/content/runs/detect/predict/traffic.mp4')
